# %%
import pandas as pd

# %%
x0 = int(input("Ingrese Semilla: "))
digitos=4
iteracion=0
Xn=x0
Ni = int(input("Ingrese el número de iteraciones: "))
LXn=[]
LXc=[]
Li=[]
LL=[]
LUi=[]
LRn=[]
while(iteracion<=Ni):
    Xc=int(Xn) * int(Xn)
    Xcs=str(Xc)
    while(len(Xcs) < 8):
        Xcs="0"+Xcs

    Longitud=len(Xcs)
    Ui=Xcs[int((Longitud/2)-2):int((Longitud/2)+2)]
    Nn="1"
    while(len(Nn)<(digitos+1)):
        Nn=Nn+"0"
    Rn=int(Ui)/int(Nn)    
    #print("Iteración: ",iteracion)
    Li.append(iteracion)
    #print("Xn: ",Xn)
    LXn.append(Xn)
    #print("Xn * Xn: ",Xcs)
    LXc.append(Xcs)
    #print("Longitud: ",Longitud)
    LL.append(Longitud)
    #print("Ui: ",Ui)
    LUi.append(Ui)
    #print(Nn)
    #print("Randomico: ",Rn)
    LRn.append(Rn)
    Xn=Ui
    iteracion=iteracion+1
    
data={'Iteracion':Li,'Xn':LXn,'Xn*Xn':LXc,'Longitud':LL,'Ui':LUi,'Rn':LRn}
df=pd.DataFrame(data)
print("Digitos: ",digitos)
df
# Out:
# Ingrese Semilla: 9880
# Ingrese el número de iteraciones: 10
# Digitos:  4
#     Iteracion    Xn     Xn*Xn  Longitud    Ui      Rn
# 0           0  9880  97614400         8  6144  0.6144
# 1           1  6144  37748736         8  7487  0.7487
# 2           2  7487  56055169         8  0551  0.0551
# 3           3  0551  00303601         8  3036  0.3036
# 4           4  3036  09217296         8  2172  0.2172
# 5           5  2172  04717584         8  7175  0.7175
# 6           6  7175  51480625         8  4806  0.4806
# 7           7  4806  23097636         8  0976  0.0976
# 8           8  0976  00952576         8  9525  0.9525
# 9           9  9525  90725625         8  7256  0.7256
# 10         10  7256  52649536         8  6495  0.6495
